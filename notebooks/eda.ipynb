# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../data/data.csv")

# %%
df.head()
# Out:
#           Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0   44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1   26858.596592   34           2        Retired    Tier_2   5371.719318
# 2   50367.605084   35           1        Student    Tier_3   7555.140763
# 3  101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4   24875.283548   52           4   Professional    Tier_2   4975.056710
#
#    Loan_Repayment    Insurance     Groceries    Transport  ...  \
# 0        0.000000  2206.490129   6658.768341  2636.970696  ...
# 1        0.000000   869.522617   2818.444460  1543.018778  ...
# 2     4612.103386  2201.800050   6313.222081  3221.396403  ...
# 3     6809.441427  4889.418087  14690.149363  7106.130005  ...
# 4     3112.609398   635.907170   3034.329665  1276.155163  ...
#
#    Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# 0      6200.537192       11265.627707                  1685.696222
# ...

# %%
df.describe()
# Out:
#              Income           Age    Dependents           Rent  \
# count  2.000000e+04  20000.000000  20000.000000   20000.000000
# mean   4.158550e+04     41.031450      1.995950    9115.494629
# std    4.001454e+04     13.578725      1.417616    9254.228188
# min    1.301187e+03     18.000000      0.000000     235.365692
# 25%    1.760488e+04     29.000000      1.000000    3649.422246
# 50%    3.018538e+04     41.000000      2.000000    6402.751824
# 75%    5.176545e+04     53.000000      3.000000   11263.940492
# max    1.079728e+06     64.000000      4.000000  215945.674703
#
#        Loan_Repayment     Insurance      Groceries     Transport  \
# count    20000.000000  20000.000000   20000.000000  20000.000000
# mean      2049.800292   1455.028761    5205.667493   2704.466685
# std       4281.789941   1492.938435    5035.953689   2666.345648
# min          0.000000     30.002012     154.078240     81.228584
# 25%          0.000000    580.204749    2165.426419   1124.578012
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
df.shape
# Out:
# (20000, 27)

# %%
missing_values = df.isnull().sum().sort_values(ascending=False)
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Income                             0
# Education                          0
# Potential_Savings_Education        0
# Potential_Savings_Healthcare       0
# Potential_Savings_Utilities        0
# Potential_Savings_Entertainment    0
# Potential_Savings_Eating_Out       0
# Potential_Savings_Transport        0
# Potential_Savings_Groceries        0
# Disposable_Income                  0
# Desired_Savings                    0
# Desired_Savings_Percentage         0
# Miscellaneous                      0
# Healthcare                         0
# Age                                0
# Utilities                          0
# Entertainment                      0
# Eating_Out                         0
# Transport                          0
# Groceries                          0
# Insurance                          0
# Loan_Repayment                     0
# Rent                               0
# City_Tier                          0
# Occupation                         0
# ...

# %%
print("Column Names:", df.columns.tolist())
# Out:
# Column Names: ['Income', 'Age', 'Dependents', 'Occupation', 'City_Tier', 'Rent', 'Loan_Repayment', 'Insurance', 'Groceries', 'Transport', 'Eating_Out', 'Entertainment', 'Utilities', 'Healthcare', 'Education', 'Miscellaneous', 'Desired_Savings_Percentage', 'Desired_Savings', 'Disposable_Income', 'Potential_Savings_Groceries', 'Potential_Savings_Transport', 'Potential_Savings_Eating_Out', 'Potential_Savings_Entertainment', 'Potential_Savings_Utilities', 'Potential_Savings_Healthcare', 'Potential_Savings_Education', 'Potential_Savings_Miscellaneous']

# %%
duplicates = df.duplicated().sum()
print(f"Duplicate rows: {duplicates}")
# Out:
# Duplicate rows: 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(df["Age"], bins=30, kde=True, color="blue")
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["Income"], bins=30, kde=True, color="blue")
plt.title("Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Age'], y=df['Income'], alpha=0.6)
plt.title("Income vs. Age")
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x="Occupation", y="Income", data=df)
plt.xticks(rotation=45)
plt.title("Income by Occupation")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="City_Tier", y="Income", data=df)
plt.title("Income vs. City Tier")
plt.show()

# %%
expense_cols = ['Rent', 'Loan_Repayment', 'Insurance', 'Groceries', 'Transport',
                'Eating_Out', 'Entertainment', 'Utilities', 'Healthcare', 'Education', 'Miscellaneous']

df[expense_cols].mean().sort_values().plot(kind='barh', figsize=(10, 6), color='skyblue')
plt.title("Average Monthly Expenses by Category")
plt.xlabel("Amount Spent")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Income'], y=df['Rent'] + df['Groceries'] + df['Entertainment'] + df['Utilities'])
plt.title("Total Monthly Expenses vs. Income")
plt.xlabel("Income")
plt.ylabel("Total Monthly Expenses")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Desired_Savings'], y=df['Disposable_Income'])
plt.title("Desired Savings vs. Disposable Income")
plt.xlabel("Desired Savings")
plt.ylabel("Disposable Income")
plt.show()

# %%
savings_cols = ['Potential_Savings_Groceries', 'Potential_Savings_Transport', 'Potential_Savings_Eating_Out', 
                'Potential_Savings_Entertainment', 'Potential_Savings_Utilities', 
                'Potential_Savings_Healthcare', 'Potential_Savings_Education', 'Potential_Savings_Miscellaneous']

df[savings_cols].mean().sort_values().plot(kind='barh', figsize=(10, 6), color='lightcoral')
plt.title("Potential Savings by Category")
plt.xlabel("Potential Savings")
plt.show()

# %%
df_encoded = df.copy()
df_encoded = pd.get_dummies(df_encoded, columns=["Occupation", "City_Tier"], drop_first=True)

plt.figure(figsize=(16, 12))
sns.heatmap(df_encoded.corr(), cmap="coolwarm", annot=True, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Feature Engineering

# %%
df = pd.get_dummies(df, columns=["Occupation", "City_Tier"], drop_first=True)

# %%
df['Savings_Ratio'] = df['Disposable_Income'] / df['Income']

# %%
essential_expenses = ["Rent", "Loan_Repayment", "Insurance", "Groceries", "Utilities", "Healthcare", "Education"]
non_essential_expenses = ["Transport", "Eating_Out", "Entertainment", "Miscellaneous"]

df["Essential_Expenses"] = df[essential_expenses].sum(axis=1)
df["Non_Essential_Expenses"] = df[non_essential_expenses].sum(axis=1)

# %%
df.head()
# Out:
#           Income  Age  Dependents          Rent  Loan_Repayment    Insurance  \
# 0   44637.249636   49           0  13391.174891        0.000000  2206.490129
# 1   26858.596592   34           2   5371.719318        0.000000   869.522617
# 2   50367.605084   35           1   7555.140763     4612.103386  2201.800050
# 3  101455.600247   21           0  15218.340037     6809.441427  4889.418087
# 4   24875.283548   52           4   4975.056710     3112.609398   635.907170
#
#       Groceries    Transport   Eating_Out  Entertainment  ...  \
# 0   6658.768341  2636.970696  1651.801726    1536.184255  ...
# 1   2818.444460  1543.018778   649.378103    1050.241738  ...
# 2   6313.222081  3221.396403  1513.814376    1723.306926  ...
# 3  14690.149363  7106.130005  5040.249158    2858.194240  ...
# 4   3034.329665  1276.155163   692.827225     660.186852  ...
#
#    Potential_Savings_Education  Potential_Savings_Miscellaneous  \
# ...

# %%
print("Column Names:", df.columns.tolist())
# Out:
# Column Names: ['Income', 'Age', 'Dependents', 'Rent', 'Loan_Repayment', 'Insurance', 'Groceries', 'Transport', 'Eating_Out', 'Entertainment', 'Utilities', 'Healthcare', 'Education', 'Miscellaneous', 'Desired_Savings_Percentage', 'Desired_Savings', 'Disposable_Income', 'Potential_Savings_Groceries', 'Potential_Savings_Transport', 'Potential_Savings_Eating_Out', 'Potential_Savings_Entertainment', 'Potential_Savings_Utilities', 'Potential_Savings_Healthcare', 'Potential_Savings_Education', 'Potential_Savings_Miscellaneous', 'Occupation_Retired', 'Occupation_Self_Employed', 'Occupation_Student', 'City_Tier_Tier_2', 'City_Tier_Tier_3', 'Savings_Ratio', 'Essential_Expenses', 'Non_Essential_Expenses']
